# %% [markdown]
# # Benchmarks con el dataset de UM

# %% [markdown]
# El siguiente Script calculara benchmarks usando el dataset de la Universidad de Murcia, creando datos sinteticos a partir de los datos reales

# %% [markdown]
# ## Importaciones

# %%
import xml.dom.minidom
import re
import uuid 
from datetime import datetime
import pickle
from pathlib import Path
from bs4 import BeautifulSoup as BS
import shutil
import os
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
import json
import scipy

# %% [markdown]
# ## Constantes

# %% [markdown]
# Expresiones Regulares

# %%
URL_REGEX = r"""(?i)\b((?:https?:(?:/{1,3}|[a-z0-9%])|[a-z0-9.\-]+[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)/)(?:[^\s()<>{}\[\]]+|\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\))+(?:\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\)|[^\s`!()\[\]{};:'".,<>?«»“”‘’])|(?:(?<!@)[a-z0-9]+(?:[.\-][a-z0-9]+)*[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)\b/?(?!@)))/"""

# %% [markdown]
# Constantes

# %%
dataNumber = [50000,250000,500000,1000000,5000000] # volumen de paquetes de datos
# dataNumber = [50000,250000,500000,1000000] # numero de datos
base_dir = './data/sintetic_data/' # directorio base de datos
GENERATE_NEW_DATA = True;
GENERATE_NEW_TDB2_MEAUSERES = True
GENERATE_NEW_BLAZEGRAPH_MEAUSERES = False

# %% [markdown]
# ## Funciones

# %% [markdown]
# Leer datos semilla

# %%
def parseRDF(path,mode,encoding='utf8'): # Read file data
    with open(path,mode, encoding=encoding) as f:
        types = set()
        RDFs = []
        rdf = ""
        in_description = False
        for line in f: # Por cada linea
            if (line.startswith("<rdf:RDF")): # Si es el principio de cada XML
                rdf = ""
                in_description = False
            elif (line.startswith("</rdf:RDF>")): # Si es el final de cada XML
                RDFs.append(rdf)
                rdf = ""
            else:
                if (line.startswith("  <rdf:Description")>0):
                    in_description = True
                elif (line.startswith("  </rdf:Description")):
                    rdf = rdf + str(line.encode(encoding, 'replace'))[2:-1].replace("\\n","\n")
                    in_description = False
                if in_description:
                    if ("<rdf:type" in line):
                        res = re.findall(URL_REGEX,line)[0].split("/")[-1] if len(re.findall(URL_REGEX,line))>0 else None
                        types.add(res)
                    rdf = rdf + str(line.encode(encoding, 'replace'))[2:-1].replace("\\n","\n") # Si es el medio del XML
        return RDFs, types

# %% [markdown]
# Tamaño en bytes de un string

# %%
def utf8len(s):
    return len(s.encode('utf-8'))

# %% [markdown]
# Expresion regular para identificar UUIDs

# %%
def create_uuid_pattern(version): # Funcion para crear regex para identificar uuid
    return re.compile(
        (
            '[a-f0-9]{8}-' +
            '[a-f0-9]{4}-' +
            version + '[a-f0-9]{3}-' +
            '[89ab][a-f0-9]{3}-' +
            '[a-f0-9]{12}'
        ),
        re.IGNORECASE
    )

# %% [markdown]
# Función para generar datos sinteticos (n) a partir de datos reales (data)

# %%
def generateData(data,n): # generacion de datos sinteticos a partir de datos reales
    if (len(data)>n):
        return data
    else:
        sintetic_data_colection = []
        sintetic_data = data.copy()
        UUID_ALL_PATTERN = create_uuid_pattern('[1-5]')
        split_size = utf8len("".join(data))
        for i in range(len(data),n): # hasta alcanzar el numero deseado
            index = i%len(data) # index in original data
            id_uuid = UUID_ALL_PATTERN.findall(RDFs[index])[0]
            if (len(id_uuid)>0):
                sintetic_data.append(RDFs[index].replace(id_uuid,str(uuid.uuid1())))
                split_size += utf8len(RDFs[index])
            if (split_size>3900000):
                sintetic_data_colection.append(sintetic_data)
                sintetic_data = []
                split_size = 0
        sintetic_data_colection.append(sintetic_data.copy())
        return sintetic_data_colection

# %% [markdown]
# Funciones para leer y escribir objetos en ficheros, util para reusar datos sinteticos

# %%
def save_obj(path, obj, name ): # Salvar objeto a fichero
    with open(path +'/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(path,name ): # leer objeto desde fichero
    with open(path +'/'+ name + '.pkl', 'rb') as f:
        return pickle.load(f)

# %% [markdown]
# ## Generación de datos sinteticos hasta máximo

# %% [markdown]
# Creación de datos sinteticos para **50K, 250K, 1M, 5M, 25M**

# %%
prefix = """<?xml version="1.0" encoding="UTF-8" ?>
    <rdf:RDF
        xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"
        xmlns:j.0="http://hercules.org/um/es-ES/rec/">
    """
sufix = """</rdf:RDF>
    """

(RDFs,t) = parseRDF('./data/rdf.log','r',encoding='utf-8')

if (GENERATE_NEW_DATA):
    if (Path(base_dir).is_dir()):
        shutil.rmtree(base_dir)
    os.mkdir(base_dir)
    dataSet = {} # Estructura
    maxData = max(dataNumber)
    print('Generating sintetic data ('+str(maxData)+')')
    now = datetime.now()
    data = generateData(RDFs,maxData)
    later = datetime.now()
    print('Data ('+str(maxData)+') is generated in '+str((later - now).total_seconds()) + ' seconds')
    
    dataLen = {}
    for dn in dataNumber:
        dataLen[dn] = 0
    
    def getDataSet(dataNumber,elements):
        for dn in dataNumber:
            if dn > elements:
                return dn
    
    counter = 0
    counterElements = 0;
    for d in data:
        counter += 1
        dataSet = getDataSet(dataLen,counterElements)
        if (dataSet-counterElements)>=len(d): # Si caben todos los elementos
            file_name = f'{base_dir}dataset_{dataSet}_number_{counter}_from_{counterElements+1}_to_{(counterElements+len(d))}.txt'
            f = open(file_name, "w")
            f.write(prefix+"".join(d)+sufix)
            f.close()
            dataLen[dataSet] = dataLen[dataSet] + len(d)
            counterElements += len(d)
            print("Create file "+file_name + ' in Set ' + str(dataSet) + ' with '+ str(len(d)) + ', new elements, remaining space available: ' + str(dataLen[dataSet]))
        else:
            size_free = dataSet-counterElements
            allowed_data = d[:size_free]
            file_name = f'{base_dir}dataset_{dataSet}_number_{counter}_from_{counterElements+1}_to_{(counterElements+len(allowed_data))}.txt'
            f = open(file_name, "w")
            f.write(prefix+("".join(allowed_data))+sufix)
            f.close()
            counterElements += len(allowed_data)
            print("Create file with allowed "+file_name + ' in Set ' + str(dataSet) + ' with '+ str(len(allowed_data)) + ', new elements, remaining space available: ' + str(dataSet-counterElements))

            # Datos restantes
            remain_data = d[size_free:]
            counter += 1
            nextDataNumber = dataNumber[dataNumber.index(dataSet)+1] if dataNumber.index(dataSet)+1 < len(dataNumber) else dataNumber.index(dataSet)
            file_name = f'{base_dir}dataset_{nextDataNumber}_number_{counter}_from_{counterElements+1}_to_{(counterElements+len(remain_data))}.txt'
            f = open(file_name, "w")
            f.write(prefix+"".join(remain_data)+sufix)
            f.close()
            counterElements += len(remain_data)
            print("Create file with remain "+file_name + ' in Set ' + str(nextDataNumber) + ' with '+ str(len(remain_data)) + ', new elements, remaining space available: ' + str(nextDataNumber-counterElements) + ' int same iteration')
# Out:
# Generating sintetic data (5000000)
# Data (5000000) is generated in 221.777097 seconds
# Create file ./data/sintetic_data/dataset_50000_number_1_from_1_to_6502.txt in Set 50000 with 6502, new elements, remaining space available: 6502
# Create file ./data/sintetic_data/dataset_50000_number_2_from_6503_to_13057.txt in Set 50000 with 6555, new elements, remaining space available: 13057
# Create file ./data/sintetic_data/dataset_50000_number_3_from_13058_to_19636.txt in Set 50000 with 6579, new elements, remaining space available: 19636
# Create file ./data/sintetic_data/dataset_50000_number_4_from_19637_to_26152.txt in Set 50000 with 6516, new elements, remaining space available: 26152
# Create file ./data/sintetic_data/dataset_50000_number_5_from_26153_to_32731.txt in Set 50000 with 6579, new elements, remaining space available: 32731
# Create file ./data/sintetic_data/dataset_50000_number_6_from_32732_to_39279.txt in Set 50000 with 6548, new elements, remaining space available: 39279
# Create file ./data/sintetic_data/dataset_50000_number_7_from_39280_to_45802.txt in Set 50000 with 6523, new elements, remaining space available: 45802
# Create file with allowed ./data/sintetic_data/dataset_50000_number_8_from_45803_to_50000.txt in Set 50000 with 4198, new elements, remaining space available: 0
# Create file with remain ./data/sintetic_data/dataset_250000_number_9_from_50001_to_52392.txt in Set 250000 with 2392, new elements, remaining space available: 197608 int same iteration
# Create file ./data/sintetic_data/dataset_250000_number_10_from_52393_to_58924.txt in Set 250000 with 6532, new elements, remaining space available: 6532
# Create file ./data/sintetic_data/dataset_250000_number_11_from_58925_to_65459.txt in Set 250000 with 6535, new elements, remaining space available: 13067
# Create file ./data/sintetic_data/dataset_250000_number_12_from_65460_to_72061.txt in Set 250000 with 6602, new elements, remaining space available: 19669
# Create file ./data/sintetic_data/dataset_250000_number_13_from_72062_to_78568.txt in Set 250000 with 6507, new elements, remaining space available: 26176
# Create file ./data/sintetic_data/dataset_250000_number_14_from_78569_to_85117.txt in Set 250000 with 6549, new elements, remaining space available: 32725
# Create file ./data/sintetic_data/dataset_250000_number_15_from_85118_to_91723.txt in Set 250000 with 6606, new elements, remaining space available: 39331
# Create file ./data/sintetic_data/dataset_250000_number_16_from_91724_to_98217.txt in Set 250000 with 6494, new elements, remaining space available: 45825
# Create file ./data/sintetic_data/dataset_250000_number_17_from_98218_to_104781.txt in Set 250000 with 6564, new elements, remaining space available: 52389
# Create file ./data/sintetic_data/dataset_250000_number_18_from_104782_to_111363.txt in Set 250000 with 6582, new elements, remaining space available: 58971
# Create file ./data/sintetic_data/dataset_250000_number_19_from_111364_to_117872.txt in Set 250000 with 6509, new elements, remaining space available: 65480
# Create file ./data/sintetic_data/dataset_250000_number_20_from_117873_to_124454.txt in Set 250000 with 6582, new elements, remaining space available: 72062
# Create file ./data/sintetic_data/dataset_250000_number_21_from_124455_to_130999.txt in Set 250000 with 6545, new elements, remaining space available: 78607
# Create file ./data/sintetic_data/dataset_250000_number_22_from_131000_to_137523.txt in Set 250000 with 6524, new elements, remaining space available: 85131
# Create file ./data/sintetic_data/dataset_250000_number_23_from_137524_to_144116.txt in Set 250000 with 6593, new elements, remaining space available: 91724
# Create file ./data/sintetic_data/dataset_250000_number_24_from_144117_to_150643.txt in Set 250000 with 6527, new elements, remaining space available: 98251
# Create file ./data/sintetic_data/dataset_250000_number_25_from_150644_to_157182.txt in Set 250000 with 6539, new elements, remaining space available: 104790
# Create file ./data/sintetic_data/dataset_250000_number_26_from_157183_to_163778.txt in Set 250000 with 6596, new elements, remaining space available: 111386
# Create file ./data/sintetic_data/dataset_250000_number_27_from_163779_to_170289.txt in Set 250000 with 6511, new elements, remaining space available: 117897
# Create file ./data/sintetic_data/dataset_250000_number_28_from_170290_to_176835.txt in Set 250000 with 6546, new elements, remaining space available: 124443
# Create file ./data/sintetic_data/dataset_250000_number_29_from_176836_to_183442.txt in Set 250000 with 6607, new elements, remaining space available: 131050
# Create file ./data/sintetic_data/dataset_250000_number_30_from_183443_to_189939.txt in Set 250000 with 6497, new elements, remaining space available: 137547
# Create file ./data/sintetic_data/dataset_250000_number_31_from_189940_to_196499.txt in Set 250000 with 6560, new elements, remaining space available: 144107
# Create file ./data/sintetic_data/dataset_250000_number_32_from_196500_to_203085.txt in Set 250000 with 6586, new elements, remaining space available: 150693
# Create file ./data/sintetic_data/dataset_250000_number_33_from_203086_to_209594.txt in Set 250000 with 6509, new elements, remaining space available: 157202
# Create file ./data/sintetic_data/dataset_250000_number_34_from_209595_to_216169.txt in Set 250000 with 6575, new elements, remaining space available: 163777
# Create file ./data/sintetic_data/dataset_250000_number_35_from_216170_to_222726.txt in Set 250000 with 6557, new elements, remaining space available: 170334
# Create file ./data/sintetic_data/dataset_250000_number_36_from_222727_to_229245.txt in Set 250000 with 6519, new elements, remaining space available: 176853
# Create file ./data/sintetic_data/dataset_250000_number_37_from_229246_to_235836.txt in Set 250000 with 6591, new elements, remaining space available: 183444
# Create file ./data/sintetic_data/dataset_250000_number_38_from_235837_to_242364.txt in Set 250000 with 6528, new elements, remaining space available: 189972
# Create file ./data/sintetic_data/dataset_250000_number_39_from_242365_to_248900.txt in Set 250000 with 6536, new elements, remaining space available: 196508
# Create file with allowed ./data/sintetic_data/dataset_250000_number_40_from_248901_to_250000.txt in Set 250000 with 1100, new elements, remaining space available: 0
# Create file with remain ./data/sintetic_data/dataset_500000_number_41_from_250001_to_255493.txt in Set 500000 with 5493, new elements, remaining space available: 244507 int same iteration
# Create file ./data/sintetic_data/dataset_500000_number_42_from_255494_to_262009.txt in Set 500000 with 6516, new elements, remaining space available: 6516
# Create file ./data/sintetic_data/dataset_500000_number_43_from_262010_to_268551.txt in Set 500000 with 6542, new elements, remaining space available: 13058
# Create file ./data/sintetic_data/dataset_500000_number_44_from_268552_to_275157.txt in Set 500000 with 6606, new elements, remaining space available: 19664
# Create file ./data/sintetic_data/dataset_500000_number_45_from_275158_to_281661.txt in Set 500000 with 6504, new elements, remaining space available: 26168
# Create file ./data/sintetic_data/dataset_500000_number_46_from_281662_to_288215.txt in Set 500000 with 6554, new elements, remaining space available: 32722
# Create file ./data/sintetic_data/dataset_500000_number_47_from_288216_to_294806.txt in Set 500000 with 6591, new elements, remaining space available: 39313
# Create file ./data/sintetic_data/dataset_500000_number_48_from_294807_to_301314.txt in Set 500000 with 6508, new elements, remaining space available: 45821
# Create file ./data/sintetic_data/dataset_500000_number_49_from_301315_to_307880.txt in Set 500000 with 6566, new elements, remaining space available: 52387
# Create file ./data/sintetic_data/dataset_500000_number_50_from_307881_to_314442.txt in Set 500000 with 6562, new elements, remaining space available: 58949
# Create file ./data/sintetic_data/dataset_500000_number_51_from_314443_to_320965.txt in Set 500000 with 6523, new elements, remaining space available: 65472
# Create file ./data/sintetic_data/dataset_500000_number_52_from_320966_to_327551.txt in Set 500000 with 6586, new elements, remaining space available: 72058
# Create file ./data/sintetic_data/dataset_500000_number_53_from_327552_to_334081.txt in Set 500000 with 6530, new elements, remaining space available: 78588
# Create file ./data/sintetic_data/dataset_500000_number_54_from_334082_to_340612.txt in Set 500000 with 6531, new elements, remaining space available: 85119
# Create file ./data/sintetic_data/dataset_500000_number_55_from_340613_to_347206.txt in Set 500000 with 6594, new elements, remaining space available: 91713
# Create file ./data/sintetic_data/dataset_500000_number_56_from_347207_to_353726.txt in Set 500000 with 6520, new elements, remaining space available: 98233
# Create file ./data/sintetic_data/dataset_500000_number_57_from_353727_to_360265.txt in Set 500000 with 6539, new elements, remaining space available: 104772
# Create file ./data/sintetic_data/dataset_500000_number_58_from_360266_to_366875.txt in Set 500000 with 6610, new elements, remaining space available: 111382
# Create file ./data/sintetic_data/dataset_500000_number_59_from_366876_to_373377.txt in Set 500000 with 6502, new elements, remaining space available: 117884
# Create file ./data/sintetic_data/dataset_500000_number_60_from_373378_to_379929.txt in Set 500000 with 6552, new elements, remaining space available: 124436
# Create file ./data/sintetic_data/dataset_500000_number_61_from_379930_to_386525.txt in Set 500000 with 6596, new elements, remaining space available: 131032
# Create file ./data/sintetic_data/dataset_500000_number_62_from_386526_to_393029.txt in Set 500000 with 6504, new elements, remaining space available: 137536
# Create file ./data/sintetic_data/dataset_500000_number_63_from_393030_to_399597.txt in Set 500000 with 6568, new elements, remaining space available: 144104
# Create file ./data/sintetic_data/dataset_500000_number_64_from_399598_to_406159.txt in Set 500000 with 6562, new elements, remaining space available: 150666
# Create file ./data/sintetic_data/dataset_500000_number_65_from_406160_to_412681.txt in Set 500000 with 6522, new elements, remaining space available: 157188
# Create file ./data/sintetic_data/dataset_500000_number_66_from_412682_to_419265.txt in Set 500000 with 6584, new elements, remaining space available: 163772
# Create file ./data/sintetic_data/dataset_500000_number_67_from_419266_to_425801.txt in Set 500000 with 6536, new elements, remaining space available: 170308
# Create file ./data/sintetic_data/dataset_500000_number_68_from_425802_to_432329.txt in Set 500000 with 6528, new elements, remaining space available: 176836
# Create file ./data/sintetic_data/dataset_500000_number_69_from_432330_to_438921.txt in Set 500000 with 6592, new elements, remaining space available: 183428
# Create file ./data/sintetic_data/dataset_500000_number_70_from_438922_to_445445.txt in Set 500000 with 6524, new elements, remaining space available: 189952
# Create file ./data/sintetic_data/dataset_500000_number_71_from_445446_to_451982.txt in Set 500000 with 6537, new elements, remaining space available: 196489
# Create file ./data/sintetic_data/dataset_500000_number_72_from_451983_to_458592.txt in Set 500000 with 6610, new elements, remaining space available: 203099
# Create file ./data/sintetic_data/dataset_500000_number_73_from_458593_to_465091.txt in Set 500000 with 6499, new elements, remaining space available: 209598
# Create file ./data/sintetic_data/dataset_500000_number_74_from_465092_to_471642.txt in Set 500000 with 6551, new elements, remaining space available: 216149
# Create file ./data/sintetic_data/dataset_500000_number_75_from_471643_to_478243.txt in Set 500000 with 6601, new elements, remaining space available: 222750
# Create file ./data/sintetic_data/dataset_500000_number_76_from_478244_to_484746.txt in Set 500000 with 6503, new elements, remaining space available: 229253
# Create file ./data/sintetic_data/dataset_500000_number_77_from_484747_to_491315.txt in Set 500000 with 6569, new elements, remaining space available: 235822
# Create file ./data/sintetic_data/dataset_500000_number_78_from_491316_to_497882.txt in Set 500000 with 6567, new elements, remaining space available: 242389
# Create file with allowed ./data/sintetic_data/dataset_500000_number_79_from_497883_to_500000.txt in Set 500000 with 2118, new elements, remaining space available: 0
# Create file with remain ./data/sintetic_data/dataset_1000000_number_80_from_500001_to_504400.txt in Set 1000000 with 4400, new elements, remaining space available: 495600 int same iteration
# Create file ./data/sintetic_data/dataset_1000000_number_81_from_504401_to_510979.txt in Set 1000000 with 6579, new elements, remaining space available: 6579
# Create file ./data/sintetic_data/dataset_1000000_number_82_from_510980_to_517524.txt in Set 1000000 with 6545, new elements, remaining space available: 13124
# Create file ./data/sintetic_data/dataset_1000000_number_83_from_517525_to_524046.txt in Set 1000000 with 6522, new elements, remaining space available: 19646
# Create file ./data/sintetic_data/dataset_1000000_number_84_from_524047_to_530641.txt in Set 1000000 with 6595, new elements, remaining space available: 26241
# Create file ./data/sintetic_data/dataset_1000000_number_85_from_530642_to_537166.txt in Set 1000000 with 6525, new elements, remaining space available: 32766
# Create file ./data/sintetic_data/dataset_1000000_number_86_from_537167_to_543707.txt in Set 1000000 with 6541, new elements, remaining space available: 39307
# Create file ./data/sintetic_data/dataset_1000000_number_87_from_543708_to_550312.txt in Set 1000000 with 6605, new elements, remaining space available: 45912
# Create file ./data/sintetic_data/dataset_1000000_number_88_from_550313_to_556816.txt in Set 1000000 with 6504, new elements, remaining space available: 52416
# Create file ./data/sintetic_data/dataset_1000000_number_89_from_556817_to_563360.txt in Set 1000000 with 6544, new elements, remaining space available: 58960
# Create file ./data/sintetic_data/dataset_1000000_number_90_from_563361_to_569967.txt in Set 1000000 with 6607, new elements, remaining space available: 65567
# Create file ./data/sintetic_data/dataset_1000000_number_91_from_569968_to_576469.txt in Set 1000000 with 6502, new elements, remaining space available: 72069
# Create file ./data/sintetic_data/dataset_1000000_number_92_from_576470_to_583025.txt in Set 1000000 with 6556, new elements, remaining space available: 78625
# Create file ./data/sintetic_data/dataset_1000000_number_93_from_583026_to_589606.txt in Set 1000000 with 6581, new elements, remaining space available: 85206
# Create file ./data/sintetic_data/dataset_1000000_number_94_from_589607_to_596120.txt in Set 1000000 with 6514, new elements, remaining space available: 91720
# Create file ./data/sintetic_data/dataset_1000000_number_95_from_596121_to_602700.txt in Set 1000000 with 6580, new elements, remaining space available: 98300
# Create file ./data/sintetic_data/dataset_1000000_number_96_from_602701_to_609248.txt in Set 1000000 with 6548, new elements, remaining space available: 104848
# Create file ./data/sintetic_data/dataset_1000000_number_97_from_609249_to_615770.txt in Set 1000000 with 6522, new elements, remaining space available: 111370
# Create file ./data/sintetic_data/dataset_1000000_number_98_from_615771_to_622361.txt in Set 1000000 with 6591, new elements, remaining space available: 117961
# Create file ./data/sintetic_data/dataset_1000000_number_99_from_622362_to_628891.txt in Set 1000000 with 6530, new elements, remaining space available: 124491
# Create file ./data/sintetic_data/dataset_1000000_number_100_from_628892_to_635427.txt in Set 1000000 with 6536, new elements, remaining space available: 131027
# Create file ./data/sintetic_data/dataset_1000000_number_101_from_635428_to_642030.txt in Set 1000000 with 6603, new elements, remaining space available: 137630
# Create file ./data/sintetic_data/dataset_1000000_number_102_from_642031_to_648537.txt in Set 1000000 with 6507, new elements, remaining space available: 144137
# Create file ./data/sintetic_data/dataset_1000000_number_103_from_648538_to_655083.txt in Set 1000000 with 6546, new elements, remaining space available: 150683
# Create file ./data/sintetic_data/dataset_1000000_number_104_from_655084_to_661689.txt in Set 1000000 with 6606, new elements, remaining space available: 157289
# Create file ./data/sintetic_data/dataset_1000000_number_105_from_661690_to_668183.txt in Set 1000000 with 6494, new elements, remaining space available: 163783
# Create file ./data/sintetic_data/dataset_1000000_number_106_from_668184_to_674747.txt in Set 1000000 with 6564, new elements, remaining space available: 170347
# Create file ./data/sintetic_data/dataset_1000000_number_107_from_674748_to_681329.txt in Set 1000000 with 6582, new elements, remaining space available: 176929
# Create file ./data/sintetic_data/dataset_1000000_number_108_from_681330_to_687838.txt in Set 1000000 with 6509, new elements, remaining space available: 183438
# Create file ./data/sintetic_data/dataset_1000000_number_109_from_687839_to_694420.txt in Set 1000000 with 6582, new elements, remaining space available: 190020
# Create file ./data/sintetic_data/dataset_1000000_number_110_from_694421_to_700965.txt in Set 1000000 with 6545, new elements, remaining space available: 196565
# Create file ./data/sintetic_data/dataset_1000000_number_111_from_700966_to_707489.txt in Set 1000000 with 6524, new elements, remaining space available: 203089
# Create file ./data/sintetic_data/dataset_1000000_number_112_from_707490_to_714082.txt in Set 1000000 with 6593, new elements, remaining space available: 209682
# Create file ./data/sintetic_data/dataset_1000000_number_113_from_714083_to_720609.txt in Set 1000000 with 6527, new elements, remaining space available: 216209
# Create file ./data/sintetic_data/dataset_1000000_number_114_from_720610_to_727148.txt in Set 1000000 with 6539, new elements, remaining space available: 222748
# Create file ./data/sintetic_data/dataset_1000000_number_115_from_727149_to_733744.txt in Set 1000000 with 6596, new elements, remaining space available: 229344
# Create file ./data/sintetic_data/dataset_1000000_number_116_from_733745_to_740255.txt in Set 1000000 with 6511, new elements, remaining space available: 235855
# Create file ./data/sintetic_data/dataset_1000000_number_117_from_740256_to_746801.txt in Set 1000000 with 6546, new elements, remaining space available: 242401
# Create file ./data/sintetic_data/dataset_1000000_number_118_from_746802_to_753408.txt in Set 1000000 with 6607, new elements, remaining space available: 249008
# Create file ./data/sintetic_data/dataset_1000000_number_119_from_753409_to_759905.txt in Set 1000000 with 6497, new elements, remaining space available: 255505
# Create file ./data/sintetic_data/dataset_1000000_number_120_from_759906_to_766465.txt in Set 1000000 with 6560, new elements, remaining space available: 262065
# Create file ./data/sintetic_data/dataset_1000000_number_121_from_766466_to_773051.txt in Set 1000000 with 6586, new elements, remaining space available: 268651
# Create file ./data/sintetic_data/dataset_1000000_number_122_from_773052_to_779560.txt in Set 1000000 with 6509, new elements, remaining space available: 275160
# Create file ./data/sintetic_data/dataset_1000000_number_123_from_779561_to_786135.txt in Set 1000000 with 6575, new elements, remaining space available: 281735
# Create file ./data/sintetic_data/dataset_1000000_number_124_from_786136_to_792692.txt in Set 1000000 with 6557, new elements, remaining space available: 288292
# Create file ./data/sintetic_data/dataset_1000000_number_125_from_792693_to_799211.txt in Set 1000000 with 6519, new elements, remaining space available: 294811
# Create file ./data/sintetic_data/dataset_1000000_number_126_from_799212_to_805802.txt in Set 1000000 with 6591, new elements, remaining space available: 301402
# Create file ./data/sintetic_data/dataset_1000000_number_127_from_805803_to_812330.txt in Set 1000000 with 6528, new elements, remaining space available: 307930
# Create file ./data/sintetic_data/dataset_1000000_number_128_from_812331_to_818866.txt in Set 1000000 with 6536, new elements, remaining space available: 314466
# Create file ./data/sintetic_data/dataset_1000000_number_129_from_818867_to_825459.txt in Set 1000000 with 6593, new elements, remaining space available: 321059
# Create file ./data/sintetic_data/dataset_1000000_number_130_from_825460_to_831975.txt in Set 1000000 with 6516, new elements, remaining space available: 327575
# Create file ./data/sintetic_data/dataset_1000000_number_131_from_831976_to_838517.txt in Set 1000000 with 6542, new elements, remaining space available: 334117
# Create file ./data/sintetic_data/dataset_1000000_number_132_from_838518_to_845123.txt in Set 1000000 with 6606, new elements, remaining space available: 340723
# Create file ./data/sintetic_data/dataset_1000000_number_133_from_845124_to_851627.txt in Set 1000000 with 6504, new elements, remaining space available: 347227
# Create file ./data/sintetic_data/dataset_1000000_number_134_from_851628_to_858181.txt in Set 1000000 with 6554, new elements, remaining space available: 353781
# Create file ./data/sintetic_data/dataset_1000000_number_135_from_858182_to_864772.txt in Set 1000000 with 6591, new elements, remaining space available: 360372
# Create file ./data/sintetic_data/dataset_1000000_number_136_from_864773_to_871280.txt in Set 1000000 with 6508, new elements, remaining space available: 366880
# Create file ./data/sintetic_data/dataset_1000000_number_137_from_871281_to_877846.txt in Set 1000000 with 6566, new elements, remaining space available: 373446
# Create file ./data/sintetic_data/dataset_1000000_number_138_from_877847_to_884408.txt in Set 1000000 with 6562, new elements, remaining space available: 380008
# Create file ./data/sintetic_data/dataset_1000000_number_139_from_884409_to_890931.txt in Set 1000000 with 6523, new elements, remaining space available: 386531
# Create file ./data/sintetic_data/dataset_1000000_number_140_from_890932_to_897517.txt in Set 1000000 with 6586, new elements, remaining space available: 393117
# Create file ./data/sintetic_data/dataset_1000000_number_141_from_897518_to_904047.txt in Set 1000000 with 6530, new elements, remaining space available: 399647
# Create file ./data/sintetic_data/dataset_1000000_number_142_from_904048_to_910578.txt in Set 1000000 with 6531, new elements, remaining space available: 406178
# Create file ./data/sintetic_data/dataset_1000000_number_143_from_910579_to_917172.txt in Set 1000000 with 6594, new elements, remaining space available: 412772
# Create file ./data/sintetic_data/dataset_1000000_number_144_from_917173_to_923692.txt in Set 1000000 with 6520, new elements, remaining space available: 419292
# Create file ./data/sintetic_data/dataset_1000000_number_145_from_923693_to_930231.txt in Set 1000000 with 6539, new elements, remaining space available: 425831
# Create file ./data/sintetic_data/dataset_1000000_number_146_from_930232_to_936841.txt in Set 1000000 with 6610, new elements, remaining space available: 432441
# Create file ./data/sintetic_data/dataset_1000000_number_147_from_936842_to_943343.txt in Set 1000000 with 6502, new elements, remaining space available: 438943
# Create file ./data/sintetic_data/dataset_1000000_number_148_from_943344_to_949895.txt in Set 1000000 with 6552, new elements, remaining space available: 445495
# Create file ./data/sintetic_data/dataset_1000000_number_149_from_949896_to_956491.txt in Set 1000000 with 6596, new elements, remaining space available: 452091
# Create file ./data/sintetic_data/dataset_1000000_number_150_from_956492_to_962995.txt in Set 1000000 with 6504, new elements, remaining space available: 458595
# Create file ./data/sintetic_data/dataset_1000000_number_151_from_962996_to_969563.txt in Set 1000000 with 6568, new elements, remaining space available: 465163
# Create file ./data/sintetic_data/dataset_1000000_number_152_from_969564_to_976125.txt in Set 1000000 with 6562, new elements, remaining space available: 471725
# Create file ./data/sintetic_data/dataset_1000000_number_153_from_976126_to_982647.txt in Set 1000000 with 6522, new elements, remaining space available: 478247
# Create file ./data/sintetic_data/dataset_1000000_number_154_from_982648_to_989231.txt in Set 1000000 with 6584, new elements, remaining space available: 484831
# Create file ./data/sintetic_data/dataset_1000000_number_155_from_989232_to_995767.txt in Set 1000000 with 6536, new elements, remaining space available: 491367
# Create file with allowed ./data/sintetic_data/dataset_1000000_number_156_from_995768_to_1000000.txt in Set 1000000 with 4233, new elements, remaining space available: 0
# Create file with remain ./data/sintetic_data/dataset_5000000_number_157_from_1000001_to_1002295.txt in Set 5000000 with 2295, new elements, remaining space available: 3997705 int same iteration
# Create file ./data/sintetic_data/dataset_5000000_number_158_from_1002296_to_1008887.txt in Set 5000000 with 6592, new elements, remaining space available: 6592
# Create file ./data/sintetic_data/dataset_5000000_number_159_from_1008888_to_1015411.txt in Set 5000000 with 6524, new elements, remaining space available: 13116
# Create file ./data/sintetic_data/dataset_5000000_number_160_from_1015412_to_1021948.txt in Set 5000000 with 6537, new elements, remaining space available: 19653
# Create file ./data/sintetic_data/dataset_5000000_number_161_from_1021949_to_1028558.txt in Set 5000000 with 6610, new elements, remaining space available: 26263
# Create file ./data/sintetic_data/dataset_5000000_number_162_from_1028559_to_1035057.txt in Set 5000000 with 6499, new elements, remaining space available: 32762
# Create file ./data/sintetic_data/dataset_5000000_number_163_from_1035058_to_1041608.txt in Set 5000000 with 6551, new elements, remaining space available: 39313
# Create file ./data/sintetic_data/dataset_5000000_number_164_from_1041609_to_1048209.txt in Set 5000000 with 6601, new elements, remaining space available: 45914
# Create file ./data/sintetic_data/dataset_5000000_number_165_from_1048210_to_1054712.txt in Set 5000000 with 6503, new elements, remaining space available: 52417
# Create file ./data/sintetic_data/dataset_5000000_number_166_from_1054713_to_1061281.txt in Set 5000000 with 6569, new elements, remaining space available: 58986
# Create file ./data/sintetic_data/dataset_5000000_number_167_from_1061282_to_1067848.txt in Set 5000000 with 6567, new elements, remaining space available: 65553
# Create file ./data/sintetic_data/dataset_5000000_number_168_from_1067849_to_1074366.txt in Set 5000000 with 6518, new elements, remaining space available: 72071
# Create file ./data/sintetic_data/dataset_5000000_number_169_from_1074367_to_1080945.txt in Set 5000000 with 6579, new elements, remaining space available: 78650
# Create file ./data/sintetic_data/dataset_5000000_number_170_from_1080946_to_1087490.txt in Set 5000000 with 6545, new elements, remaining space available: 85195
# Create file ./data/sintetic_data/dataset_5000000_number_171_from_1087491_to_1094012.txt in Set 5000000 with 6522, new elements, remaining space available: 91717
# Create file ./data/sintetic_data/dataset_5000000_number_172_from_1094013_to_1100607.txt in Set 5000000 with 6595, new elements, remaining space available: 98312
# Create file ./data/sintetic_data/dataset_5000000_number_173_from_1100608_to_1107132.txt in Set 5000000 with 6525, new elements, remaining space available: 104837
# Create file ./data/sintetic_data/dataset_5000000_number_174_from_1107133_to_1113673.txt in Set 5000000 with 6541, new elements, remaining space available: 111378
# Create file ./data/sintetic_data/dataset_5000000_number_175_from_1113674_to_1120278.txt in Set 5000000 with 6605, new elements, remaining space available: 117983
# Create file ./data/sintetic_data/dataset_5000000_number_176_from_1120279_to_1126782.txt in Set 5000000 with 6504, new elements, remaining space available: 124487
# Create file ./data/sintetic_data/dataset_5000000_number_177_from_1126783_to_1133326.txt in Set 5000000 with 6544, new elements, remaining space available: 131031
# Create file ./data/sintetic_data/dataset_5000000_number_178_from_1133327_to_1139933.txt in Set 5000000 with 6607, new elements, remaining space available: 137638
# Create file ./data/sintetic_data/dataset_5000000_number_179_from_1139934_to_1146435.txt in Set 5000000 with 6502, new elements, remaining space available: 144140
# Create file ./data/sintetic_data/dataset_5000000_number_180_from_1146436_to_1152991.txt in Set 5000000 with 6556, new elements, remaining space available: 150696
# Create file ./data/sintetic_data/dataset_5000000_number_181_from_1152992_to_1159572.txt in Set 5000000 with 6581, new elements, remaining space available: 157277
# Create file ./data/sintetic_data/dataset_5000000_number_182_from_1159573_to_1166086.txt in Set 5000000 with 6514, new elements, remaining space available: 163791
# Create file ./data/sintetic_data/dataset_5000000_number_183_from_1166087_to_1172666.txt in Set 5000000 with 6580, new elements, remaining space available: 170371
# Create file ./data/sintetic_data/dataset_5000000_number_184_from_1172667_to_1179214.txt in Set 5000000 with 6548, new elements, remaining space available: 176919
# Create file ./data/sintetic_data/dataset_5000000_number_185_from_1179215_to_1185736.txt in Set 5000000 with 6522, new elements, remaining space available: 183441
# Create file ./data/sintetic_data/dataset_5000000_number_186_from_1185737_to_1192327.txt in Set 5000000 with 6591, new elements, remaining space available: 190032
# Create file ./data/sintetic_data/dataset_5000000_number_187_from_1192328_to_1198857.txt in Set 5000000 with 6530, new elements, remaining space available: 196562
# Create file ./data/sintetic_data/dataset_5000000_number_188_from_1198858_to_1205393.txt in Set 5000000 with 6536, new elements, remaining space available: 203098
# Create file ./data/sintetic_data/dataset_5000000_number_189_from_1205394_to_1211996.txt in Set 5000000 with 6603, new elements, remaining space available: 209701
# Create file ./data/sintetic_data/dataset_5000000_number_190_from_1211997_to_1218503.txt in Set 5000000 with 6507, new elements, remaining space available: 216208
# Create file ./data/sintetic_data/dataset_5000000_number_191_from_1218504_to_1225049.txt in Set 5000000 with 6546, new elements, remaining space available: 222754
# Create file ./data/sintetic_data/dataset_5000000_number_192_from_1225050_to_1231655.txt in Set 5000000 with 6606, new elements, remaining space available: 229360
# Create file ./data/sintetic_data/dataset_5000000_number_193_from_1231656_to_1238149.txt in Set 5000000 with 6494, new elements, remaining space available: 235854
# Create file ./data/sintetic_data/dataset_5000000_number_194_from_1238150_to_1244713.txt in Set 5000000 with 6564, new elements, remaining space available: 242418
# Create file ./data/sintetic_data/dataset_5000000_number_195_from_1244714_to_1251295.txt in Set 5000000 with 6582, new elements, remaining space available: 249000
# Create file ./data/sintetic_data/dataset_5000000_number_196_from_1251296_to_1257804.txt in Set 5000000 with 6509, new elements, remaining space available: 255509
# Create file ./data/sintetic_data/dataset_5000000_number_197_from_1257805_to_1264386.txt in Set 5000000 with 6582, new elements, remaining space available: 262091
# Create file ./data/sintetic_data/dataset_5000000_number_198_from_1264387_to_1270931.txt in Set 5000000 with 6545, new elements, remaining space available: 268636
# Create file ./data/sintetic_data/dataset_5000000_number_199_from_1270932_to_1277455.txt in Set 5000000 with 6524, new elements, remaining space available: 275160
# Create file ./data/sintetic_data/dataset_5000000_number_200_from_1277456_to_1284048.txt in Set 5000000 with 6593, new elements, remaining space available: 281753
# Create file ./data/sintetic_data/dataset_5000000_number_201_from_1284049_to_1290575.txt in Set 5000000 with 6527, new elements, remaining space available: 288280
# Create file ./data/sintetic_data/dataset_5000000_number_202_from_1290576_to_1297114.txt in Set 5000000 with 6539, new elements, remaining space available: 294819
# Create file ./data/sintetic_data/dataset_5000000_number_203_from_1297115_to_1303710.txt in Set 5000000 with 6596, new elements, remaining space available: 301415
# Create file ./data/sintetic_data/dataset_5000000_number_204_from_1303711_to_1310221.txt in Set 5000000 with 6511, new elements, remaining space available: 307926
# Create file ./data/sintetic_data/dataset_5000000_number_205_from_1310222_to_1316767.txt in Set 5000000 with 6546, new elements, remaining space available: 314472
# Create file ./data/sintetic_data/dataset_5000000_number_206_from_1316768_to_1323374.txt in Set 5000000 with 6607, new elements, remaining space available: 321079
# Create file ./data/sintetic_data/dataset_5000000_number_207_from_1323375_to_1329871.txt in Set 5000000 with 6497, new elements, remaining space available: 327576
# Create file ./data/sintetic_data/dataset_5000000_number_208_from_1329872_to_1336431.txt in Set 5000000 with 6560, new elements, remaining space available: 334136
# Create file ./data/sintetic_data/dataset_5000000_number_209_from_1336432_to_1343017.txt in Set 5000000 with 6586, new elements, remaining space available: 340722
# Create file ./data/sintetic_data/dataset_5000000_number_210_from_1343018_to_1349526.txt in Set 5000000 with 6509, new elements, remaining space available: 347231
# Create file ./data/sintetic_data/dataset_5000000_number_211_from_1349527_to_1356101.txt in Set 5000000 with 6575, new elements, remaining space available: 353806
# Create file ./data/sintetic_data/dataset_5000000_number_212_from_1356102_to_1362658.txt in Set 5000000 with 6557, new elements, remaining space available: 360363
# Create file ./data/sintetic_data/dataset_5000000_number_213_from_1362659_to_1369177.txt in Set 5000000 with 6519, new elements, remaining space available: 366882
# Create file ./data/sintetic_data/dataset_5000000_number_214_from_1369178_to_1375768.txt in Set 5000000 with 6591, new elements, remaining space available: 373473
# Create file ./data/sintetic_data/dataset_5000000_number_215_from_1375769_to_1382296.txt in Set 5000000 with 6528, new elements, remaining space available: 380001
# Create file ./data/sintetic_data/dataset_5000000_number_216_from_1382297_to_1388832.txt in Set 5000000 with 6536, new elements, remaining space available: 386537
# Create file ./data/sintetic_data/dataset_5000000_number_217_from_1388833_to_1395425.txt in Set 5000000 with 6593, new elements, remaining space available: 393130
# Create file ./data/sintetic_data/dataset_5000000_number_218_from_1395426_to_1401941.txt in Set 5000000 with 6516, new elements, remaining space available: 399646
# Create file ./data/sintetic_data/dataset_5000000_number_219_from_1401942_to_1408483.txt in Set 5000000 with 6542, new elements, remaining space available: 406188
# Create file ./data/sintetic_data/dataset_5000000_number_220_from_1408484_to_1415089.txt in Set 5000000 with 6606, new elements, remaining space available: 412794
# Create file ./data/sintetic_data/dataset_5000000_number_221_from_1415090_to_1421593.txt in Set 5000000 with 6504, new elements, remaining space available: 419298
# Create file ./data/sintetic_data/dataset_5000000_number_222_from_1421594_to_1428147.txt in Set 5000000 with 6554, new elements, remaining space available: 425852
# Create file ./data/sintetic_data/dataset_5000000_number_223_from_1428148_to_1434738.txt in Set 5000000 with 6591, new elements, remaining space available: 432443
# Create file ./data/sintetic_data/dataset_5000000_number_224_from_1434739_to_1441246.txt in Set 5000000 with 6508, new elements, remaining space available: 438951
# Create file ./data/sintetic_data/dataset_5000000_number_225_from_1441247_to_1447812.txt in Set 5000000 with 6566, new elements, remaining space available: 445517
# Create file ./data/sintetic_data/dataset_5000000_number_226_from_1447813_to_1454374.txt in Set 5000000 with 6562, new elements, remaining space available: 452079
# Create file ./data/sintetic_data/dataset_5000000_number_227_from_1454375_to_1460897.txt in Set 5000000 with 6523, new elements, remaining space available: 458602
# Create file ./data/sintetic_data/dataset_5000000_number_228_from_1460898_to_1467483.txt in Set 5000000 with 6586, new elements, remaining space available: 465188
# Create file ./data/sintetic_data/dataset_5000000_number_229_from_1467484_to_1474013.txt in Set 5000000 with 6530, new elements, remaining space available: 471718
# Create file ./data/sintetic_data/dataset_5000000_number_230_from_1474014_to_1480544.txt in Set 5000000 with 6531, new elements, remaining space available: 478249
# Create file ./data/sintetic_data/dataset_5000000_number_231_from_1480545_to_1487138.txt in Set 5000000 with 6594, new elements, remaining space available: 484843
# Create file ./data/sintetic_data/dataset_5000000_number_232_from_1487139_to_1493658.txt in Set 5000000 with 6520, new elements, remaining space available: 491363
# Create file ./data/sintetic_data/dataset_5000000_number_233_from_1493659_to_1500197.txt in Set 5000000 with 6539, new elements, remaining space available: 497902
# Create file ./data/sintetic_data/dataset_5000000_number_234_from_1500198_to_1506807.txt in Set 5000000 with 6610, new elements, remaining space available: 504512
# Create file ./data/sintetic_data/dataset_5000000_number_235_from_1506808_to_1513309.txt in Set 5000000 with 6502, new elements, remaining space available: 511014
# Create file ./data/sintetic_data/dataset_5000000_number_236_from_1513310_to_1519861.txt in Set 5000000 with 6552, new elements, remaining space available: 517566
# Create file ./data/sintetic_data/dataset_5000000_number_237_from_1519862_to_1526457.txt in Set 5000000 with 6596, new elements, remaining space available: 524162
# Create file ./data/sintetic_data/dataset_5000000_number_238_from_1526458_to_1532961.txt in Set 5000000 with 6504, new elements, remaining space available: 530666
# Create file ./data/sintetic_data/dataset_5000000_number_239_from_1532962_to_1539529.txt in Set 5000000 with 6568, new elements, remaining space available: 537234
# Create file ./data/sintetic_data/dataset_5000000_number_240_from_1539530_to_1546091.txt in Set 5000000 with 6562, new elements, remaining space available: 543796
# Create file ./data/sintetic_data/dataset_5000000_number_241_from_1546092_to_1552613.txt in Set 5000000 with 6522, new elements, remaining space available: 550318
# Create file ./data/sintetic_data/dataset_5000000_number_242_from_1552614_to_1559197.txt in Set 5000000 with 6584, new elements, remaining space available: 556902
# Create file ./data/sintetic_data/dataset_5000000_number_243_from_1559198_to_1565733.txt in Set 5000000 with 6536, new elements, remaining space available: 563438
# Create file ./data/sintetic_data/dataset_5000000_number_244_from_1565734_to_1572261.txt in Set 5000000 with 6528, new elements, remaining space available: 569966
# Create file ./data/sintetic_data/dataset_5000000_number_245_from_1572262_to_1578853.txt in Set 5000000 with 6592, new elements, remaining space available: 576558
# Create file ./data/sintetic_data/dataset_5000000_number_246_from_1578854_to_1585377.txt in Set 5000000 with 6524, new elements, remaining space available: 583082
# Create file ./data/sintetic_data/dataset_5000000_number_247_from_1585378_to_1591914.txt in Set 5000000 with 6537, new elements, remaining space available: 589619
# Create file ./data/sintetic_data/dataset_5000000_number_248_from_1591915_to_1598524.txt in Set 5000000 with 6610, new elements, remaining space available: 596229
# Create file ./data/sintetic_data/dataset_5000000_number_249_from_1598525_to_1605023.txt in Set 5000000 with 6499, new elements, remaining space available: 602728
# Create file ./data/sintetic_data/dataset_5000000_number_250_from_1605024_to_1611574.txt in Set 5000000 with 6551, new elements, remaining space available: 609279
# Create file ./data/sintetic_data/dataset_5000000_number_251_from_1611575_to_1618175.txt in Set 5000000 with 6601, new elements, remaining space available: 615880
# Create file ./data/sintetic_data/dataset_5000000_number_252_from_1618176_to_1624678.txt in Set 5000000 with 6503, new elements, remaining space available: 622383
# Create file ./data/sintetic_data/dataset_5000000_number_253_from_1624679_to_1631247.txt in Set 5000000 with 6569, new elements, remaining space available: 628952
# Create file ./data/sintetic_data/dataset_5000000_number_254_from_1631248_to_1637814.txt in Set 5000000 with 6567, new elements, remaining space available: 635519
# Create file ./data/sintetic_data/dataset_5000000_number_255_from_1637815_to_1644332.txt in Set 5000000 with 6518, new elements, remaining space available: 642037
# Create file ./data/sintetic_data/dataset_5000000_number_256_from_1644333_to_1650911.txt in Set 5000000 with 6579, new elements, remaining space available: 648616
# Create file ./data/sintetic_data/dataset_5000000_number_257_from_1650912_to_1657456.txt in Set 5000000 with 6545, new elements, remaining space available: 655161
# Create file ./data/sintetic_data/dataset_5000000_number_258_from_1657457_to_1663978.txt in Set 5000000 with 6522, new elements, remaining space available: 661683
# Create file ./data/sintetic_data/dataset_5000000_number_259_from_1663979_to_1670573.txt in Set 5000000 with 6595, new elements, remaining space available: 668278
# Create file ./data/sintetic_data/dataset_5000000_number_260_from_1670574_to_1677098.txt in Set 5000000 with 6525, new elements, remaining space available: 674803
# Create file ./data/sintetic_data/dataset_5000000_number_261_from_1677099_to_1683639.txt in Set 5000000 with 6541, new elements, remaining space available: 681344
# Create file ./data/sintetic_data/dataset_5000000_number_262_from_1683640_to_1690244.txt in Set 5000000 with 6605, new elements, remaining space available: 687949
# Create file ./data/sintetic_data/dataset_5000000_number_263_from_1690245_to_1696748.txt in Set 5000000 with 6504, new elements, remaining space available: 694453
# Create file ./data/sintetic_data/dataset_5000000_number_264_from_1696749_to_1703292.txt in Set 5000000 with 6544, new elements, remaining space available: 700997
# Create file ./data/sintetic_data/dataset_5000000_number_265_from_1703293_to_1709899.txt in Set 5000000 with 6607, new elements, remaining space available: 707604
# Create file ./data/sintetic_data/dataset_5000000_number_266_from_1709900_to_1716401.txt in Set 5000000 with 6502, new elements, remaining space available: 714106
# Create file ./data/sintetic_data/dataset_5000000_number_267_from_1716402_to_1722957.txt in Set 5000000 with 6556, new elements, remaining space available: 720662
# Create file ./data/sintetic_data/dataset_5000000_number_268_from_1722958_to_1729538.txt in Set 5000000 with 6581, new elements, remaining space available: 727243
# Create file ./data/sintetic_data/dataset_5000000_number_269_from_1729539_to_1736052.txt in Set 5000000 with 6514, new elements, remaining space available: 733757
# Create file ./data/sintetic_data/dataset_5000000_number_270_from_1736053_to_1742632.txt in Set 5000000 with 6580, new elements, remaining space available: 740337
# Create file ./data/sintetic_data/dataset_5000000_number_271_from_1742633_to_1749180.txt in Set 5000000 with 6548, new elements, remaining space available: 746885
# Create file ./data/sintetic_data/dataset_5000000_number_272_from_1749181_to_1755702.txt in Set 5000000 with 6522, new elements, remaining space available: 753407
# Create file ./data/sintetic_data/dataset_5000000_number_273_from_1755703_to_1762293.txt in Set 5000000 with 6591, new elements, remaining space available: 759998
# Create file ./data/sintetic_data/dataset_5000000_number_274_from_1762294_to_1768823.txt in Set 5000000 with 6530, new elements, remaining space available: 766528
# Create file ./data/sintetic_data/dataset_5000000_number_275_from_1768824_to_1775359.txt in Set 5000000 with 6536, new elements, remaining space available: 773064
# Create file ./data/sintetic_data/dataset_5000000_number_276_from_1775360_to_1781962.txt in Set 5000000 with 6603, new elements, remaining space available: 779667
# Create file ./data/sintetic_data/dataset_5000000_number_277_from_1781963_to_1788469.txt in Set 5000000 with 6507, new elements, remaining space available: 786174
# Create file ./data/sintetic_data/dataset_5000000_number_278_from_1788470_to_1795015.txt in Set 5000000 with 6546, new elements, remaining space available: 792720
# Create file ./data/sintetic_data/dataset_5000000_number_279_from_1795016_to_1801621.txt in Set 5000000 with 6606, new elements, remaining space available: 799326
# Create file ./data/sintetic_data/dataset_5000000_number_280_from_1801622_to_1808115.txt in Set 5000000 with 6494, new elements, remaining space available: 805820
# Create file ./data/sintetic_data/dataset_5000000_number_281_from_1808116_to_1814679.txt in Set 5000000 with 6564, new elements, remaining space available: 812384
# Create file ./data/sintetic_data/dataset_5000000_number_282_from_1814680_to_1821261.txt in Set 5000000 with 6582, new elements, remaining space available: 818966
# Create file ./data/sintetic_data/dataset_5000000_number_283_from_1821262_to_1827770.txt in Set 5000000 with 6509, new elements, remaining space available: 825475
# Create file ./data/sintetic_data/dataset_5000000_number_284_from_1827771_to_1834352.txt in Set 5000000 with 6582, new elements, remaining space available: 832057
# Create file ./data/sintetic_data/dataset_5000000_number_285_from_1834353_to_1840897.txt in Set 5000000 with 6545, new elements, remaining space available: 838602
# Create file ./data/sintetic_data/dataset_5000000_number_286_from_1840898_to_1847421.txt in Set 5000000 with 6524, new elements, remaining space available: 845126
# Create file ./data/sintetic_data/dataset_5000000_number_287_from_1847422_to_1854014.txt in Set 5000000 with 6593, new elements, remaining space available: 851719
# Create file ./data/sintetic_data/dataset_5000000_number_288_from_1854015_to_1860541.txt in Set 5000000 with 6527, new elements, remaining space available: 858246
# Create file ./data/sintetic_data/dataset_5000000_number_289_from_1860542_to_1867080.txt in Set 5000000 with 6539, new elements, remaining space available: 864785
# Create file ./data/sintetic_data/dataset_5000000_number_290_from_1867081_to_1873676.txt in Set 5000000 with 6596, new elements, remaining space available: 871381
# Create file ./data/sintetic_data/dataset_5000000_number_291_from_1873677_to_1880187.txt in Set 5000000 with 6511, new elements, remaining space available: 877892
# Create file ./data/sintetic_data/dataset_5000000_number_292_from_1880188_to_1886733.txt in Set 5000000 with 6546, new elements, remaining space available: 884438
# Create file ./data/sintetic_data/dataset_5000000_number_293_from_1886734_to_1893340.txt in Set 5000000 with 6607, new elements, remaining space available: 891045
# Create file ./data/sintetic_data/dataset_5000000_number_294_from_1893341_to_1899837.txt in Set 5000000 with 6497, new elements, remaining space available: 897542
# Create file ./data/sintetic_data/dataset_5000000_number_295_from_1899838_to_1906397.txt in Set 5000000 with 6560, new elements, remaining space available: 904102
# Create file ./data/sintetic_data/dataset_5000000_number_296_from_1906398_to_1912983.txt in Set 5000000 with 6586, new elements, remaining space available: 910688
# Create file ./data/sintetic_data/dataset_5000000_number_297_from_1912984_to_1919492.txt in Set 5000000 with 6509, new elements, remaining space available: 917197
# Create file ./data/sintetic_data/dataset_5000000_number_298_from_1919493_to_1926067.txt in Set 5000000 with 6575, new elements, remaining space available: 923772
# Create file ./data/sintetic_data/dataset_5000000_number_299_from_1926068_to_1932624.txt in Set 5000000 with 6557, new elements, remaining space available: 930329
# ...
# Create file ./data/sintetic_data/dataset_5000000_number_671_from_4363140_to_4369691.txt in Set 5000000 with 6552, new elements, remaining space available: 3367396
# Create file ./data/sintetic_data/dataset_5000000_number_672_from_4369692_to_4376287.txt in Set 5000000 with 6596, new elements, remaining space available: 3373992
# Create file ./data/sintetic_data/dataset_5000000_number_673_from_4376288_to_4382791.txt in Set 5000000 with 6504, new elements, remaining space available: 3380496
# Create file ./data/sintetic_data/dataset_5000000_number_674_from_4382792_to_4389359.txt in Set 5000000 with 6568, new elements, remaining space available: 3387064
# Create file ./data/sintetic_data/dataset_5000000_number_675_from_4389360_to_4395921.txt in Set 5000000 with 6562, new elements, remaining space available: 3393626
# Create file ./data/sintetic_data/dataset_5000000_number_676_from_4395922_to_4402443.txt in Set 5000000 with 6522, new elements, remaining space available: 3400148
# Create file ./data/sintetic_data/dataset_5000000_number_677_from_4402444_to_4409027.txt in Set 5000000 with 6584, new elements, remaining space available: 3406732
# Create file ./data/sintetic_data/dataset_5000000_number_678_from_4409028_to_4415563.txt in Set 5000000 with 6536, new elements, remaining space available: 3413268
# Create file ./data/sintetic_data/dataset_5000000_number_679_from_4415564_to_4422091.txt in Set 5000000 with 6528, new elements, remaining space available: 3419796
# Create file ./data/sintetic_data/dataset_5000000_number_680_from_4422092_to_4428683.txt in Set 5000000 with 6592, new elements, remaining space available: 3426388
# Create file ./data/sintetic_data/dataset_5000000_number_681_from_4428684_to_4435207.txt in Set 5000000 with 6524, new elements, remaining space available: 3432912
# Create file ./data/sintetic_data/dataset_5000000_number_682_from_4435208_to_4441744.txt in Set 5000000 with 6537, new elements, remaining space available: 3439449
# Create file ./data/sintetic_data/dataset_5000000_number_683_from_4441745_to_4448354.txt in Set 5000000 with 6610, new elements, remaining space available: 3446059
# Create file ./data/sintetic_data/dataset_5000000_number_684_from_4448355_to_4454853.txt in Set 5000000 with 6499, new elements, remaining space available: 3452558
# Create file ./data/sintetic_data/dataset_5000000_number_685_from_4454854_to_4461404.txt in Set 5000000 with 6551, new elements, remaining space available: 3459109
# Create file ./data/sintetic_data/dataset_5000000_number_686_from_4461405_to_4468005.txt in Set 5000000 with 6601, new elements, remaining space available: 3465710
# Create file ./data/sintetic_data/dataset_5000000_number_687_from_4468006_to_4474508.txt in Set 5000000 with 6503, new elements, remaining space available: 3472213
# Create file ./data/sintetic_data/dataset_5000000_number_688_from_4474509_to_4481077.txt in Set 5000000 with 6569, new elements, remaining space available: 3478782
# Create file ./data/sintetic_data/dataset_5000000_number_689_from_4481078_to_4487644.txt in Set 5000000 with 6567, new elements, remaining space available: 3485349
# Create file ./data/sintetic_data/dataset_5000000_number_690_from_4487645_to_4494162.txt in Set 5000000 with 6518, new elements, remaining space available: 3491867
# Create file ./data/sintetic_data/dataset_5000000_number_691_from_4494163_to_4500741.txt in Set 5000000 with 6579, new elements, remaining space available: 3498446
# Create file ./data/sintetic_data/dataset_5000000_number_692_from_4500742_to_4507286.txt in Set 5000000 with 6545, new elements, remaining space available: 3504991
# Create file ./data/sintetic_data/dataset_5000000_number_693_from_4507287_to_4513808.txt in Set 5000000 with 6522, new elements, remaining space available: 3511513
# Create file ./data/sintetic_data/dataset_5000000_number_694_from_4513809_to_4520403.txt in Set 5000000 with 6595, new elements, remaining space available: 3518108
# Create file ./data/sintetic_data/dataset_5000000_number_695_from_4520404_to_4526928.txt in Set 5000000 with 6525, new elements, remaining space available: 3524633
# Create file ./data/sintetic_data/dataset_5000000_number_696_from_4526929_to_4533469.txt in Set 5000000 with 6541, new elements, remaining space available: 3531174
# Create file ./data/sintetic_data/dataset_5000000_number_697_from_4533470_to_4540074.txt in Set 5000000 with 6605, new elements, remaining space available: 3537779
# Create file ./data/sintetic_data/dataset_5000000_number_698_from_4540075_to_4546578.txt in Set 5000000 with 6504, new elements, remaining space available: 3544283
# Create file ./data/sintetic_data/dataset_5000000_number_699_from_4546579_to_4553122.txt in Set 5000000 with 6544, new elements, remaining space available: 3550827
# Create file ./data/sintetic_data/dataset_5000000_number_700_from_4553123_to_4559729.txt in Set 5000000 with 6607, new elements, remaining space available: 3557434
# Create file ./data/sintetic_data/dataset_5000000_number_701_from_4559730_to_4566231.txt in Set 5000000 with 6502, new elements, remaining space available: 3563936
# Create file ./data/sintetic_data/dataset_5000000_number_702_from_4566232_to_4572787.txt in Set 5000000 with 6556, new elements, remaining space available: 3570492
# Create file ./data/sintetic_data/dataset_5000000_number_703_from_4572788_to_4579368.txt in Set 5000000 with 6581, new elements, remaining space available: 3577073
# Create file ./data/sintetic_data/dataset_5000000_number_704_from_4579369_to_4585882.txt in Set 5000000 with 6514, new elements, remaining space available: 3583587
# Create file ./data/sintetic_data/dataset_5000000_number_705_from_4585883_to_4592462.txt in Set 5000000 with 6580, new elements, remaining space available: 3590167
# Create file ./data/sintetic_data/dataset_5000000_number_706_from_4592463_to_4599010.txt in Set 5000000 with 6548, new elements, remaining space available: 3596715
# Create file ./data/sintetic_data/dataset_5000000_number_707_from_4599011_to_4605532.txt in Set 5000000 with 6522, new elements, remaining space available: 3603237
# Create file ./data/sintetic_data/dataset_5000000_number_708_from_4605533_to_4612123.txt in Set 5000000 with 6591, new elements, remaining space available: 3609828
# Create file ./data/sintetic_data/dataset_5000000_number_709_from_4612124_to_4618653.txt in Set 5000000 with 6530, new elements, remaining space available: 3616358
# Create file ./data/sintetic_data/dataset_5000000_number_710_from_4618654_to_4625189.txt in Set 5000000 with 6536, new elements, remaining space available: 3622894
# Create file ./data/sintetic_data/dataset_5000000_number_711_from_4625190_to_4631792.txt in Set 5000000 with 6603, new elements, remaining space available: 3629497
# Create file ./data/sintetic_data/dataset_5000000_number_712_from_4631793_to_4638299.txt in Set 5000000 with 6507, new elements, remaining space available: 3636004
# Create file ./data/sintetic_data/dataset_5000000_number_713_from_4638300_to_4644845.txt in Set 5000000 with 6546, new elements, remaining space available: 3642550
# Create file ./data/sintetic_data/dataset_5000000_number_714_from_4644846_to_4651451.txt in Set 5000000 with 6606, new elements, remaining space available: 3649156
# Create file ./data/sintetic_data/dataset_5000000_number_715_from_4651452_to_4657945.txt in Set 5000000 with 6494, new elements, remaining space available: 3655650
# Create file ./data/sintetic_data/dataset_5000000_number_716_from_4657946_to_4664509.txt in Set 5000000 with 6564, new elements, remaining space available: 3662214
# Create file ./data/sintetic_data/dataset_5000000_number_717_from_4664510_to_4671091.txt in Set 5000000 with 6582, new elements, remaining space available: 3668796
# Create file ./data/sintetic_data/dataset_5000000_number_718_from_4671092_to_4677600.txt in Set 5000000 with 6509, new elements, remaining space available: 3675305
# Create file ./data/sintetic_data/dataset_5000000_number_719_from_4677601_to_4684182.txt in Set 5000000 with 6582, new elements, remaining space available: 3681887
# Create file ./data/sintetic_data/dataset_5000000_number_720_from_4684183_to_4690727.txt in Set 5000000 with 6545, new elements, remaining space available: 3688432
# Create file ./data/sintetic_data/dataset_5000000_number_721_from_4690728_to_4697251.txt in Set 5000000 with 6524, new elements, remaining space available: 3694956
# Create file ./data/sintetic_data/dataset_5000000_number_722_from_4697252_to_4703844.txt in Set 5000000 with 6593, new elements, remaining space available: 3701549
# Create file ./data/sintetic_data/dataset_5000000_number_723_from_4703845_to_4710371.txt in Set 5000000 with 6527, new elements, remaining space available: 3708076
# Create file ./data/sintetic_data/dataset_5000000_number_724_from_4710372_to_4716910.txt in Set 5000000 with 6539, new elements, remaining space available: 3714615
# Create file ./data/sintetic_data/dataset_5000000_number_725_from_4716911_to_4723506.txt in Set 5000000 with 6596, new elements, remaining space available: 3721211
# Create file ./data/sintetic_data/dataset_5000000_number_726_from_4723507_to_4730017.txt in Set 5000000 with 6511, new elements, remaining space available: 3727722
# Create file ./data/sintetic_data/dataset_5000000_number_727_from_4730018_to_4736563.txt in Set 5000000 with 6546, new elements, remaining space available: 3734268
# Create file ./data/sintetic_data/dataset_5000000_number_728_from_4736564_to_4743170.txt in Set 5000000 with 6607, new elements, remaining space available: 3740875
# Create file ./data/sintetic_data/dataset_5000000_number_729_from_4743171_to_4749667.txt in Set 5000000 with 6497, new elements, remaining space available: 3747372
# Create file ./data/sintetic_data/dataset_5000000_number_730_from_4749668_to_4756227.txt in Set 5000000 with 6560, new elements, remaining space available: 3753932
# Create file ./data/sintetic_data/dataset_5000000_number_731_from_4756228_to_4762813.txt in Set 5000000 with 6586, new elements, remaining space available: 3760518
# Create file ./data/sintetic_data/dataset_5000000_number_732_from_4762814_to_4769322.txt in Set 5000000 with 6509, new elements, remaining space available: 3767027
# Create file ./data/sintetic_data/dataset_5000000_number_733_from_4769323_to_4775897.txt in Set 5000000 with 6575, new elements, remaining space available: 3773602
# Create file ./data/sintetic_data/dataset_5000000_number_734_from_4775898_to_4782454.txt in Set 5000000 with 6557, new elements, remaining space available: 3780159
# Create file ./data/sintetic_data/dataset_5000000_number_735_from_4782455_to_4788973.txt in Set 5000000 with 6519, new elements, remaining space available: 3786678
# Create file ./data/sintetic_data/dataset_5000000_number_736_from_4788974_to_4795564.txt in Set 5000000 with 6591, new elements, remaining space available: 3793269
# Create file ./data/sintetic_data/dataset_5000000_number_737_from_4795565_to_4802092.txt in Set 5000000 with 6528, new elements, remaining space available: 3799797
# Create file ./data/sintetic_data/dataset_5000000_number_738_from_4802093_to_4808628.txt in Set 5000000 with 6536, new elements, remaining space available: 3806333
# Create file ./data/sintetic_data/dataset_5000000_number_739_from_4808629_to_4815221.txt in Set 5000000 with 6593, new elements, remaining space available: 3812926
# Create file ./data/sintetic_data/dataset_5000000_number_740_from_4815222_to_4821737.txt in Set 5000000 with 6516, new elements, remaining space available: 3819442
# Create file ./data/sintetic_data/dataset_5000000_number_741_from_4821738_to_4828279.txt in Set 5000000 with 6542, new elements, remaining space available: 3825984
# Create file ./data/sintetic_data/dataset_5000000_number_742_from_4828280_to_4834885.txt in Set 5000000 with 6606, new elements, remaining space available: 3832590
# Create file ./data/sintetic_data/dataset_5000000_number_743_from_4834886_to_4841389.txt in Set 5000000 with 6504, new elements, remaining space available: 3839094
# Create file ./data/sintetic_data/dataset_5000000_number_744_from_4841390_to_4847943.txt in Set 5000000 with 6554, new elements, remaining space available: 3845648
# Create file ./data/sintetic_data/dataset_5000000_number_745_from_4847944_to_4854534.txt in Set 5000000 with 6591, new elements, remaining space available: 3852239
# Create file ./data/sintetic_data/dataset_5000000_number_746_from_4854535_to_4861042.txt in Set 5000000 with 6508, new elements, remaining space available: 3858747
# Create file ./data/sintetic_data/dataset_5000000_number_747_from_4861043_to_4867608.txt in Set 5000000 with 6566, new elements, remaining space available: 3865313
# Create file ./data/sintetic_data/dataset_5000000_number_748_from_4867609_to_4874170.txt in Set 5000000 with 6562, new elements, remaining space available: 3871875
# Create file ./data/sintetic_data/dataset_5000000_number_749_from_4874171_to_4880693.txt in Set 5000000 with 6523, new elements, remaining space available: 3878398
# Create file ./data/sintetic_data/dataset_5000000_number_750_from_4880694_to_4887279.txt in Set 5000000 with 6586, new elements, remaining space available: 3884984
# Create file ./data/sintetic_data/dataset_5000000_number_751_from_4887280_to_4893809.txt in Set 5000000 with 6530, new elements, remaining space available: 3891514
# Create file ./data/sintetic_data/dataset_5000000_number_752_from_4893810_to_4900340.txt in Set 5000000 with 6531, new elements, remaining space available: 3898045
# Create file ./data/sintetic_data/dataset_5000000_number_753_from_4900341_to_4906934.txt in Set 5000000 with 6594, new elements, remaining space available: 3904639
# Create file ./data/sintetic_data/dataset_5000000_number_754_from_4906935_to_4913454.txt in Set 5000000 with 6520, new elements, remaining space available: 3911159
# Create file ./data/sintetic_data/dataset_5000000_number_755_from_4913455_to_4919993.txt in Set 5000000 with 6539, new elements, remaining space available: 3917698
# Create file ./data/sintetic_data/dataset_5000000_number_756_from_4919994_to_4926603.txt in Set 5000000 with 6610, new elements, remaining space available: 3924308
# Create file ./data/sintetic_data/dataset_5000000_number_757_from_4926604_to_4933105.txt in Set 5000000 with 6502, new elements, remaining space available: 3930810
# Create file ./data/sintetic_data/dataset_5000000_number_758_from_4933106_to_4939657.txt in Set 5000000 with 6552, new elements, remaining space available: 3937362
# Create file ./data/sintetic_data/dataset_5000000_number_759_from_4939658_to_4946253.txt in Set 5000000 with 6596, new elements, remaining space available: 3943958
# Create file ./data/sintetic_data/dataset_5000000_number_760_from_4946254_to_4952757.txt in Set 5000000 with 6504, new elements, remaining space available: 3950462
# Create file ./data/sintetic_data/dataset_5000000_number_761_from_4952758_to_4959325.txt in Set 5000000 with 6568, new elements, remaining space available: 3957030
# Create file ./data/sintetic_data/dataset_5000000_number_762_from_4959326_to_4965887.txt in Set 5000000 with 6562, new elements, remaining space available: 3963592
# Create file ./data/sintetic_data/dataset_5000000_number_763_from_4965888_to_4972409.txt in Set 5000000 with 6522, new elements, remaining space available: 3970114
# Create file ./data/sintetic_data/dataset_5000000_number_764_from_4972410_to_4978993.txt in Set 5000000 with 6584, new elements, remaining space available: 3976698
# Create file ./data/sintetic_data/dataset_5000000_number_765_from_4978994_to_4985529.txt in Set 5000000 with 6536, new elements, remaining space available: 3983234
# Create file ./data/sintetic_data/dataset_5000000_number_766_from_4985530_to_4992057.txt in Set 5000000 with 6528, new elements, remaining space available: 3989762
# Create file ./data/sintetic_data/dataset_5000000_number_767_from_4992058_to_4998649.txt in Set 5000000 with 6592, new elements, remaining space available: 3996354
# Create file ./data/sintetic_data/dataset_5000000_number_768_from_4998650_to_5000000.txt in Set 5000000 with 1351, new elements, remaining space available: 3997705

# %% [markdown]
# ## Queries

# %% [markdown]
# Obtener el numero total de tripletas

# %%
Q1 = """PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>

DESCRIBE <http://hercules.org/um/es-ES/rec/AnualidadFinanciacionRegistroAyudaDefinitiva/e73fc9ee-382e-4a83-b9d5-58d3c45c5d81>"""

Q1_N = """
DESCRIBE <http://hercules.org/um/es-ES/rec/AnualidadFinanciacionRegistroAyudaDefinitiva/e73fc9ee-382e-4a83-b9d5-58d3c45c5d81>"""


# COUNT: Contar el numero de tripletas
Q2 = """PREFIX un: <http://www.w3.org/2007/ont/unit#>
PREFIX uni: <http://purl.org/weso/uni/uni.html#>
prefix univ:<http://people.brunel.ac.uk/~csstnns/university.owl#>
prefix sp:<http://www.meta-qsar.org/ontologies/sport.owl#>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT (COUNT(*) as ?Triples) WHERE { ?s ?p ?o}"""

Q2_N = """SELECT (COUNT(*) as ?Triples) WHERE { ?s ?p ?o}"""

# FILTER: WHERE idPersona = 2211
Q3 = """PREFIX un: <http://www.w3.org/2007/ont/unit#>
PREFIX uni: <http://purl.org/weso/uni/uni.html#>
prefix univ:<http://people.brunel.ac.uk/~csstnns/university.owl#>
prefix sp:<http://www.meta-qsar.org/ontologies/sport.owl#>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT ?s ?p ?o
WHERE {
  # ?s <http://hercules.org/um/es-ES/rec/idPersona> ?o
  FILTER(?o = "2211")
}"""

Q3_N = """SELECT ?s ?p ?o
WHERE {
  # ?s <http://hercules.org/um/es-ES/rec/idPersona> ?o
  FILTER(?o = "2211")
}"""

# DISTINCT: Personas distintas
Q4 = """PREFIX un: <http://www.w3.org/2007/ont/unit#>
PREFIX uni: <http://purl.org/weso/uni/uni.html#>
prefix univ:<http://people.brunel.ac.uk/~csstnns/university.owl#>
prefix sp:<http://www.meta-qsar.org/ontologies/sport.owl#>
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>

SELECT DISTINCT ?o WHERE { ?s <http://hercules.org/um/es-ES/rec/idPersona> ?o }"""

Q4_N = """SELECT DISTINCT ?o WHERE { ?s <http://hercules.org/um/es-ES/rec/idPersona> ?o }"""


queries = [Q1,Q2,Q3,Q4]

queries_no_prefix = [Q1_N,Q2_N,Q3_N,Q4_N]

# %% [markdown]
# ## General Triple Stores

# %% [markdown]
# Método para realizar la petición Post para 1 fichero

# %%
def sendDataFromFile(filePath,host='localhost',port=3030,url='/trellis/data?graph=trellis'):
    import http.client
    import mimetypes
    conn = http.client.HTTPConnection(host, port)
    dataList = []
    boundary = 'wL36Yn8afVp8Ag7AmP8qZ0SA4n1v9T'
    dataList.append('--' + boundary)
    dataList.append('Content-Disposition: form-data; name=file; filename={0}'.format(filePath))

    fileType = mimetypes.guess_type(filePath)[0] or 'application/octet-stream'
    dataList.append('Content-Type: {}'.format(fileType))
    dataList.append('')

    with open(filePath) as f:
      dataList.append(f.read())
    dataList.append('--'+boundary+'--')
    dataList.append('')
    body = '\r\n'.join(dataList)
    payload = body
    headers = {
       'Content-type': 'multipart/form-data; boundary={}'.format(boundary) 
    }
    conn.request("POST", url, payload, headers)
    res = conn.getresponse()
    data = res.read()
    return data.decode("utf-8")

# %%
def sendDataFromFileBlazegraph(filePath,host='localhost',port=8889,url='/bigdata/sparql'):
    import requests
    dataList = []
    with open(filePath) as f:
        dataList.append(f.read())
    body = '\r\n'.join(dataList)
    payload = body
    headers = {
      'Content-Type': 'application/rdf+xml'
    }
    response = requests.request("POST", 'http://'+host+':'+str(port)+url, headers=headers, data = payload)

    return  response.text

# %%
#sendDataFromFileBlazegraph(filePath='./data/sintetic_data/dataset_50000_number_1_from_1_to_6502.txt')

# %% [markdown]
# Método para realizar una query

# %%
def sendQuery(query,host='localhost',port=3030,url='/trellis/data?graph=trellis'):
    import http.client
    import mimetypes
    import urllib.parse
    conn = http.client.HTTPConnection("localhost", 3030)
    payload = f'query={query}'
    headers = {
      'Content-Type': 'application/x-www-form-urlencoded',
      'Accept': 'application/json'
    }
    conn.request("POST", "/trellis/sparql", payload, headers)
    res = conn.getresponse()
    data = res.read()
    return data.decode("utf-8")

# %%
def sendQueryBlazegraph(query,host='localhost',port=8889,url='/bigdata/sparql'):
    import requests

    url = f"http://{host}:{port}/bigdata/sparql?query={query}"

    payload = {}
    headers = {
      'Accept': 'application/json'
    }

    response = requests.request("POST", url, headers=headers, data = payload)

    return response.text

# %% [markdown]
# ### FUSEKI + TDB2

# %%
if GENERATE_NEW_TDB2_MEAUSERES:
    updateTime = []
    queryTime = []
    for dn in dataNumber:

        nowUpdate = datetime.now() # Comienzo de momento actual para cada grupo

        # Insercion
        for f in os.listdir(base_dir):
            setData = int(re.search(r'\d+', f).group()) # Obtengo grupo

            if dn == setData: # Si pertenece al grupo
                res = sendDataFromFile(filePath=f'{base_dir}{f}') # Envio el dato
                print(dn)
        # Finalizado el grupo
        laterUpdate = datetime.now() # Tiempo final para el grupo

            # Tiempo empleado para Updates
        deltaUpdate = laterUpdate - nowUpdate
        if len(updateTime)>0: # Si procese la iteracion update anterior
            updateTime.append({'set': dn,'start': nowUpdate, 'end': laterUpdate ,'deltaTime': deltaUpdate.total_seconds(),'acumDeltaTime': deltaUpdate.total_seconds() + updateTime[len(updateTime)-1]['acumDeltaTime']})
        else:
            updateTime.append({'set': dn,'start': nowUpdate, 'end': laterUpdate ,'deltaTime': deltaUpdate.total_seconds(),'acumDeltaTime': deltaUpdate.total_seconds()})

        # Tiempo empleado para Queries
        counter_q = 0
        queryTimeObj = {'set': dn, 'queries':[] }
        for q in queries:
            counter_q += 1
            now_q = datetime.now()
            result = sendQuery(q)
            later_q = datetime.now()
            delta_q = later_q - now_q
            queryTimeObj['queries'].append({'start': now_q, 'end': later_q, 'deltaTime': delta_q.total_seconds(), 'queryId': f'Q{counter_q}', 'query': q})
        queryTime.append(queryTimeObj)

    import pandas as pd
    udf = pd.DataFrame(columns=['elements','delta_time_seg','amount_delta_time_seg'])
    for ut in updateTime:
        udf = udf.append({'elements': ut['set'],'delta_time_seg': ut['deltaTime'],'amount_delta_time_seg': ut['acumDeltaTime']}, ignore_index=True)
    udf.to_csv('./results/updateMetricFuseki.csv', index=False)
    qdf = pd.DataFrame(columns=['elements','Q1_delta_time_seg','Q2_delta_time_seg','Q3_delta_time_seg','Q4_delta_time_seg'])
    for qt in queryTime:
        qtObj = {'elements':qt['set']}
        for q in qt['queries']:
            qtObj[f"{q['queryId']}_delta_time_seg"]=q['deltaTime']
        qdf = qdf.append(qtObj, ignore_index=True)
    qdf.to_csv('./results/queriesMetricFuseki.csv', index=False)
# Out:
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 50000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 250000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 500000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 1000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000
# 5000000

# %% [markdown]
# ### BlazeGraph

# %%
if GENERATE_NEW_BLAZEGRAPH_MEAUSERES:
    updateTime = []
    queryTime = []
    for dn in dataNumber:

        nowUpdate = datetime.now() # Comienzo de momento actual para cada grupo

        # Insercion
        for f in os.listdir(base_dir):
            setData = int(re.search(r'\d+', f).group()) # Obtengo grupo

            if dn == setData: # Si pertenece al grupo
                res = sendDataFromFileBlazegraph(filePath=f'{base_dir}{f}') # Envio el dato
                print(res)
        # Finalizado el grupo
        laterUpdate = datetime.now() # Tiempo final para el grupo

            # Tiempo empleado para Updates
        deltaUpdate = laterUpdate - nowUpdate
        if len(updateTime)>0: # Si procese la iteracion update anterior
            updateTime.append({'set': dn,'start': nowUpdate, 'end': laterUpdate ,'deltaTime': deltaUpdate.total_seconds(),'acumDeltaTime': deltaUpdate.total_seconds() + updateTime[len(updateTime)-1]['acumDeltaTime']})
        else:
            updateTime.append({'set': dn,'start': nowUpdate, 'end': laterUpdate ,'deltaTime': deltaUpdate.total_seconds(),'acumDeltaTime': deltaUpdate.total_seconds()})

        # Tiempo empleado para Queries
        counter_q = 0
        queryTimeObj = {'set': dn, 'queries':[] }
        for q in queries_no_prefix:
            counter_q += 1
            now_q = datetime.now()
            result = sendQueryBlazegraph(q)
            later_q = datetime.now()
            delta_q = later_q - now_q
            queryTimeObj['queries'].append({'start': now_q, 'end': later_q, 'deltaTime': delta_q.total_seconds(), 'queryId': f'Q{counter_q}', 'query': q})
        queryTime.append(queryTimeObj)

    import pandas as pd
    udf = pd.DataFrame(columns=['elements','delta_time_seg','amount_delta_time_seg'])
    for ut in updateTime:
        udf = udf.append({'elements': ut['set'],'delta_time_seg': ut['deltaTime'],'amount_delta_time_seg': ut['acumDeltaTime']}, ignore_index=True)
    udf.to_csv('./results/updateMetricBlazegraph.csv', index=False)
    qdf = pd.DataFrame(columns=['elements','Q1_delta_time_seg','Q2_delta_time_seg','Q3_delta_time_seg','Q4_delta_time_seg'])
    for qt in queryTime:
        qtObj = {'elements':qt['set']}
        for q in qt['queries']:
            qtObj[f"{q['queryId']}_delta_time_seg"]=q['deltaTime']
        qdf = qdf.append(qtObj, ignore_index=True)
    qdf.to_csv('./results/queriesMetricBlazegraph.csv', index=False)

# %% [markdown]
# Leer datos

# %%
updateFuseki = pd.read_csv('./results/updateMetricFuseki.csv') 
updateBlazeGraph = pd.read_csv('./results/updateMetricBlazegraph.csv') 
queriesFuseki = pd.read_csv('./results/queriesMetricFuseki.csv') 
queriesBlazegraph = pd.read_csv('./results/queriesMetricBlazegraph.csv')

# %% [markdown]
# Combinar datos

# %%
comparativeUpdates = pd.DataFrame(
    {
        'fuseki': list(updateFuseki['delta_time_seg']), 
        'blazegraph': list(updateBlazeGraph['delta_time_seg'])
    }
)

# %%
comparativeUpdates
# Out:
#        fuseki   blazegraph
# 0    6.593503     3.359767
# 1   18.553377    17.131264
# 2   26.531804    43.918947
# 3   55.428372   165.398358
# 4  493.131946  2552.058824

# %%
rankedUpdates = comparativeUpdates.eq(comparativeUpdates.where(comparativeUpdates != 0).min(1), axis=0).astype(int)

# %%
comparativeQueries = pd.DataFrame(
    {
        'fuseki_Q1': list(queriesFuseki['Q1_delta_time_seg']), 
        'fuseki_Q2': list(queriesFuseki['Q2_delta_time_seg']), 
        'fuseki_Q3': list(queriesFuseki['Q3_delta_time_seg']), 
        'fuseki_Q4': list(queriesFuseki['Q4_delta_time_seg']), 
        'blazegraph_Q1': list(queriesBlazegraph['Q1_delta_time_seg']), 
        'blazegraph_Q2': list(queriesBlazegraph['Q2_delta_time_seg']), 
        'blazegraph_Q3': list(queriesBlazegraph['Q3_delta_time_seg']), 
        'blazegraph_Q4': list(queriesBlazegraph['Q4_delta_time_seg']), 
    }
)

# %%
comparativeQueries[['fuseki_Q3','blazegraph_Q3']]
# Out:
#    fuseki_Q3  blazegraph_Q3
# 0   1.066817       0.502146
# 1   0.881751       0.639660
# 2   1.008468       1.429181
# 3   0.927235       2.954163
# 4   1.004720      16.448291

# %%
rankedUpdates = pd.DataFrame()
rankedUpdates[['fuseki_Q1','blazegraph_Q1']] = comparativeQueries[['fuseki_Q1','blazegraph_Q1']].eq(comparativeQueries[['fuseki_Q1','blazegraph_Q1']].min(1), axis=0).astype(int)
rankedUpdates[['fuseki_Q2','blazegraph_Q2']] = comparativeQueries[['fuseki_Q2','blazegraph_Q2']].eq(comparativeQueries[['fuseki_Q2','blazegraph_Q2']].min(1), axis=0).astype(int)
rankedUpdates[['fuseki_Q3','blazegraph_Q3']] = comparativeQueries[['fuseki_Q3','blazegraph_Q3']].eq(comparativeQueries[['fuseki_Q3','blazegraph_Q3']].min(1), axis=0).astype(int)
rankedUpdates[['fuseki_Q4','blazegraph_Q4']] = comparativeQueries[['fuseki_Q4','blazegraph_Q4']].eq(comparativeQueries[['fuseki_Q4','blazegraph_Q4']].min(1), axis=0).astype(int)

# %%
comparativeQueries.iloc[0][4]
# Out:
# 0.033353

# %%
comparativeQueries
# Out:
#    fuseki_Q1  fuseki_Q2  fuseki_Q3  fuseki_Q4  blazegraph_Q1  blazegraph_Q2  \
# 0   0.067700  15.351222   1.066817   7.800106       0.033353       0.022999
# 1   0.013002  23.949527   0.881751   7.956429       0.036598       0.021998
# 2   0.010995  30.055681   1.008468   8.378793       0.075981       0.022996
# 3   0.011002  31.073240   0.927235   8.034584       0.053015       0.032986
# 4   0.010017  36.973381   1.004720  10.692471       0.085023       0.036953
#
#    blazegraph_Q3  blazegraph_Q4
# 0       0.502146       0.028001
# 1       0.639660       0.013734
# 2       1.429181       0.027963
# 3       2.954163       0.027038
# 4      16.448291       0.059030

# %% [markdown]
# ## Enviar datos a Firebase

# %% [markdown]
# Preparar los resultados

# %%
import json

with open('./data/measures.json') as f:
  data = json.load(f)
  tables = data['benchmarks'][1]['metrics'][0]['tables'];

  
tables[0] ={
    'name': 'Tiempo (de lectura) en BlazeGraph',
    'description': 'Tiempo medio de lectura para todas las queries testedas por média aritmética',
    'table': {
        'columns': ['#Items','#RDFs (aprox.)','Query 1','Query 2','Query 3','Query 4','Média Aritmética'],
        'rows': [
            ['50k','400k',comparativeQueries.iloc[0][4],comparativeQueries.iloc[0][5],comparativeQueries.iloc[0][6],comparativeQueries.iloc[0][7],np.mean(comparativeQueries.iloc[0][4:])],
            ['250k','2M',comparativeQueries.iloc[1][4],comparativeQueries.iloc[1][5],comparativeQueries.iloc[1][6],comparativeQueries.iloc[1][7],np.mean(comparativeQueries.iloc[0][4:])],
            ['500k','4M',comparativeQueries.iloc[2][4],comparativeQueries.iloc[2][5],comparativeQueries.iloc[2][6],comparativeQueries.iloc[2][7],np.mean(comparativeQueries.iloc[0][4:])],
            ['1M','8M',comparativeQueries.iloc[3][4],comparativeQueries.iloc[3][5],comparativeQueries.iloc[3][6],comparativeQueries.iloc[3][7],np.mean(comparativeQueries.iloc[0][4:])],
            ['5M','20M',comparativeQueries.iloc[4][4],comparativeQueries.iloc[4][5],comparativeQueries.iloc[4][6],comparativeQueries.iloc[4][7],np.mean(comparativeQueries.iloc[0][4:])]
        ]
    },
}
tables[1] ={
    'name': 'Tiempo (de lectura) en TDB2',
    'description': 'Tiempo medio de lectura para todas las queries testedas por média aritmética',
    'table': {
        'columns': ['#Items','#RDFs (aprox.)','Query 1','Query 2','Query 3','Query 4','Média Aritmética'],
        'rows': [
            ['50k','400k',comparativeQueries.iloc[0][0],comparativeQueries.iloc[0][1],comparativeQueries.iloc[0][2],comparativeQueries.iloc[0][3],np.mean(comparativeQueries.iloc[0][0:4])],
            ['250k','2M',comparativeQueries.iloc[1][0],comparativeQueries.iloc[1][1],comparativeQueries.iloc[1][2],comparativeQueries.iloc[1][3],np.mean(comparativeQueries.iloc[0][0:4])],
            ['500k','4M',comparativeQueries.iloc[2][0],comparativeQueries.iloc[2][1],comparativeQueries.iloc[2][2],comparativeQueries.iloc[2][3],np.mean(comparativeQueries.iloc[0][0:4])],
            ['1M','8M',comparativeQueries.iloc[3][0],comparativeQueries.iloc[3][1],comparativeQueries.iloc[3][2],comparativeQueries.iloc[3][3],np.mean(comparativeQueries.iloc[0][0:4])],
            ['5M','20M',comparativeQueries.iloc[4][0],comparativeQueries.iloc[4][1],comparativeQueries.iloc[4][2],comparativeQueries.iloc[4][3],np.mean(comparativeQueries.iloc[0][0:4])]
        ]
    },
}
tables[2] ={
    'name': 'Agregado de Tiempo Medio (Lectura)',
    'description': 'Tiempo medio de lectura para todos los conjuntos de datos testeados y media aritmética',
    'table': {
        'columns': ['#Items','#RDFs (aprox.)','BlazeGraph','TDB2'],
        'rows': [
            ['50k','400k',np.mean(comparativeQueries.iloc[0][4:]),np.mean(comparativeQueries.iloc[0][0:4])],
            ['250k','2M',np.mean(comparativeQueries.iloc[1][4:]),np.mean(comparativeQueries.iloc[1][0:4])],
            ['500k','4M',np.mean(comparativeQueries.iloc[2][4:]),np.mean(comparativeQueries.iloc[2][0:4])],
            ['1M','8M',np.mean(comparativeQueries.iloc[3][4:]),np.mean(comparativeQueries.iloc[3][0:4])],
            ['5M','20M',np.mean(comparativeQueries.iloc[4][4:]),np.mean(comparativeQueries.iloc[4][0:4])]
        ]
    },
}
readAggregate = pd.DataFrame.from_records( tables[2]['table']['rows'] ).iloc[:,2:4]
readAggregateRanked = readAggregate.eq(readAggregate.where(readAggregate != 0).min(1), axis=0).astype(int)
tables[3] ={
    'name': 'Tiempo (Lectura): Frecuencia de ranking y puntuacion final',
    'description': 'Frecuencia de ranking y puntuacion final para triplestores analizados, mediada por tiempo medio por media aritmetica, la puntuación total se calcula multiplicando x2 la frecuencia de 1º posición y x1 la frecuencia de 2º posición',
    'table': {
        'columns': ['#Frec','BlazeGraph','TDB2'],
        'rows': [
            ['#1',len(readAggregateRanked[(readAggregateRanked[2]==1)]),len(readAggregateRanked[(readAggregateRanked[3]==1)]) ],
            ['#2',len(readAggregateRanked[(readAggregateRanked[2]==0)]),len(readAggregateRanked[(readAggregateRanked[3]==0)]) ],
            ['Puntuación',len(readAggregateRanked[(readAggregateRanked[2]==1)])*2 + len(readAggregateRanked[(readAggregateRanked[2]==0)]),len(readAggregateRanked[(readAggregateRanked[3]==1)])*2 + len(readAggregateRanked[(readAggregateRanked[3]==0)]) ],
        ]
    },
}

tables[4] ={
    'name': 'Agregado de Tiempo Medio (Escritura)',
    'description': 'Tiempo medio de escritura para todos los conjuntos de datos testeados y media aritmética',
    'table': {
        'columns': ['#Items','#RDFs (aprox.)','BlazeGraph','TDB2'],
        'rows': [
            ['50k','400k',comparativeUpdates.iloc[:,1][0],comparativeUpdates.iloc[:,0][0]],
            ['250k','2M',comparativeUpdates.iloc[:,1][1],comparativeUpdates.iloc[:,0][1]],
            ['500k','4M',comparativeUpdates.iloc[:,1][2],comparativeUpdates.iloc[:,0][2]],
            ['1M','8M',comparativeUpdates.iloc[:,1][3],comparativeUpdates.iloc[:,0][3]],
            ['5M','20M',comparativeUpdates.iloc[:,1][4],comparativeUpdates.iloc[:,0][4]]
        ]
    },
}
updateAggregate = pd.DataFrame.from_records( tables[4]['table']['rows'] ).iloc[:,2:4]
updateAggregateRanked = readAggregate.eq(readAggregate.where(readAggregate != 0).min(1), axis=0).astype(int)
tables[3] ={
    'name': 'Tiempo (Lectura): Frecuencia de ranking y puntuacion final',
    'description': 'Frecuencia de ranking y puntuacion final para triplestores analizados, mediada por tiempo medio por media aritmetica, la puntuación total se calcula multiplicando x2 la frecuencia de 1º posición y x1 la frecuencia de 2º posición',
    'table': {
        'columns': ['#Frec','BlazeGraph','TDB2'],
        'rows': [
            ['#1',len(readAggregateRanked[(readAggregateRanked[2]==1)]),len(readAggregateRanked[(readAggregateRanked[3]==1)]) ],
            ['#2',len(readAggregateRanked[(readAggregateRanked[2]==0)]),len(readAggregateRanked[(readAggregateRanked[3]==0)]) ],
            ['Puntuación',len(readAggregateRanked[(readAggregateRanked[2]==1)])*2 + len(readAggregateRanked[(readAggregateRanked[2]==0)]),len(readAggregateRanked[(readAggregateRanked[3]==1)])*2 + len(readAggregateRanked[(readAggregateRanked[3]==0)]) ],
        ]
    },
}
#updateAggregate = pd.DataFrame.from_records( tables[5]['table']['rows'] ).iloc[:,2:4]
#updateAggregateRanked = readAggregate.eq(readAggregate.where(readAggregate != 0).min(1), axis=0).astype(int)


print(tables[5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d2f40ff79ed> in <module>
#      13         'columns': ['#Items','#RDFs (aprox.)','Query 1','Query 2','Query 3','Query 4','Média Aritmética'],
#      14         'rows': [
# ---> 15             ['50k','400k',comparativeQueries.iloc[0][4],comparativeQueries.iloc[0][5],comparativeQueries.iloc[0][6],comparativeQueries.iloc[0][7],np.mean(comparativeQueries.iloc[0][4:])],
#      16             ['250k','2M',comparativeQueries.iloc[1][4],comparativeQueries.iloc[1][5],comparativeQueries.iloc[1][6],comparativeQueries.iloc[1][7],np.mean(comparativeQueries.iloc[0][4:])],
#      17             ['500k','4M',comparativeQueries.iloc[2][4],comparativeQueries.iloc[2][5],comparativeQueries.iloc[2][6],comparativeQueries.iloc[2][7],np.mean(comparativeQueries.iloc[0][4:])],
#
# NameError: name 'comparativeQueries' is not defined

# %%
updateAggregate = pd.DataFrame.from_records( tables[4]['table']['rows'] ).iloc[:,2:4]
updateAggregateRanked = readAggregate.eq(readAggregate.where(readAggregate != 0).min(1), axis=0).astype(int)

# %%
updateAggregateRanked
# Out:
#    1  2
# 0  2  3
# 1  3  2
# 2  7  8

# %%
tables[6] ={
    'name': 'Frecuencia de ranking y puntuacion final en Lectura y escritura',
    'description': 'Suma de las Frecuencias de ranking y puntuacion final anteriores',
    'table': {
        'columns': ['#Frec','BlazeGraph','TDB2'],
        'rows': [
            ['#suma',tables[5]['table']['rows'],len(readAggregateRanked[(readAggregateRanked[3]==1)]) ],
            ['#2',len(readAggregateRanked[(readAggregateRanked[2]==0)]),len(readAggregateRanked[(readAggregateRanked[3]==0)]) ],
            ['Puntuación',len(readAggregateRanked[(readAggregateRanked[2]==1)])*2 + len(readAggregateRanked[(readAggregateRanked[2]==0)]),len(readAggregateRanked[(readAggregateRanked[3]==1)])*2 + len(readAggregateRanked[(readAggregateRanked[3]==0)]) ],
        ]
    },
}
# Out:
# [['50k', '400k', 3.3597669999999997, 6.593503],
#  ['250k', '2M', 17.131264, 18.553376999999998],
#  ['500k', '4M', 43.918946999999996, 26.531803999999998],
#  ['1M', '8M', 165.398358, 55.428371999999996],
#  ['5M', '20M', 2552.0588239999997, 493.13194599999997]]

# %%
['Puntuación',len(updateAggregateRanked[(updateAggregateRanked[2]==1)])*2 + len(updateAggregateRanked[(updateAggregateRanked[2]==0)]),len(updateAggregateRanked[(updateAggregateRanked[3]==1)])*2 + len(updateAggregateRanked[(updateAggregateRanked[3]==0)]) ]
# Out:
# ['Puntuación', 7, 8]

# %%
tables[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-262-0e94159ea35c> in <module>
# ----> 1 tables[7]
#
# IndexError: list index out of range

# %%
readAgregate
# Out:
#           2          3
# 0  0.146625   6.071461
# 1  0.177998   8.200177
# 2  0.389030   9.863484
# 3  0.766801  10.011515
# 4  4.157324  12.170147

# %%
ranking = readAgregate.eq(readAgregate.where(readAgregate != 0).min(1), axis=0).astype(int)

# %%
readAgregate[readAgregate.columns[0]]
# Out:
# 0    0.146625
# 1    0.177998
# 2    0.389030
# 3    0.766801
# 4    4.157324
# Name: 2, dtype: float64

# %%
ranking[ranking.iloc[:,0]==1].count()
# Out:
# 2    5
# 3    5
# dtype: int64

# %%
np.count(ranking.iloc[:,0] == 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-212-2be82c1aad56> in <module>
# ----> 1 np.count(ranking.iloc[:,0] == 1)
#
# AttributeError: module 'numpy' has no attribute 'count'

# %%
len(ranking[(ranking[2]==1)])
# Out:
# 5

# %%
len(ranking[(ranking[2]==0)])
# Out:
# 0
